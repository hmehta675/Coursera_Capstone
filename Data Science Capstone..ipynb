# %% [markdown]
# This notebook is used to build the Data Science Capstone Project

# %%
import numpy as np

# %%
import pandas as pd

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
#https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/abff4cce-2873-4114-93aa-9258cb8503f1?projectid=dc46c4a8-5710-4850-bafe-a5b9a8b4f455&context=wdp
